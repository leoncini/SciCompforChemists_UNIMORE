# %% [markdown]
# # <span style="color:red">Introduzione per CdL in Chimica</span>
#
# Il materiale presente nel repository <span style="color:blue">SciCompforChemists_UNIMORE</span> rappresenta una fork del repository <a href="https://weisscharlesj.github.io/SciCompforChemists/notebooks/introduction/intro.html">SciCompforChemists di Charles J. Weiss</a> parzialmente adattato per l'insegnamento di Informatica del Corso di Laurea in Chimica
#
# &Egrave; previsto lo svolgimento, in tutto o in parte, dei seguenti capitoli presenti nel repository originale
#
# 1. Capitolo 1: Basic Python
# 2. Capitolo 2: Intermediate Python
# 3. Capitolo 3: Plotting with Matplotlib
# 4. Capitolo 4: Numpy
# 5. Capitolo 5: Pandas
# 6. Capitolo 8: Matematica (simbolica)
# 7. Capitolo 10: Plotting with Seaborn
# 8. Capitolo 12: Machine Learning using Scikit-Learn
# 9. Capitolo 13: Command Line & Spyder
# 10. Capitolo 14: Optimization and Root Finding
# 11. Capitolo 16: Bioinformatics with Biopython and Nglview
#
# Nel repostory esiste anche un'appendice <span style="color:blue">appendix_00</span> che potra essere inclusa nel programma solo in un secondo momento.
#
# Ogni capitolo è un file presente sul repository. Si tratta di file di tipo <span style="color:blue">jupyter notebooks</span>, file cioè in cui è possibile inserire **testo e grafica**, come ad esempio in un file MS Word, ma anche **codice Python** che può essere eseguito, se il notebook è collegato ad un interprete del linguaggio (detto <span style="color:blue">kernel</span>). I notebook sono file con estensione **ipynb**.
#
# Per poter utilmente visulizzare un file ipynb ed eseguire il codice python in esso (eventualmente) contenuto, è necessario avere installato software opportuno. Le macchine del laboratorio hanno installato tale software. Tuttavia, si tratta di macchine che possiamo etichettare come **computer senza memoria**. Questo vuol dire che allo spegnimento, il lavoro svolto (ovvero le eventuali modifiche apportate al/ai notebook) viene perrduto. Non solo per poter svolgere esercizi a casa, ma anche per le lezioni in laboratorio è dunque consigliabile che ogni studente utilizzi il proprio **computer portatile, con il software necessario.
#
# Il modo più semplice di procedere è di installare un unico pacchetto software, chiamato <span style="color:blue">Anaconda</span>. Nel notebook <span style="color:blue">chap__00_notebook.ipynb</span> sono riportate istruzioni dettagliate. Tuttavia, per aprire tale notebook con le istruzioni per installare Anaconda è necessario disporre di Anaconda... Un problema circolare. Per questa ragione, nel repository è comunque presente la versione pdf di tale notebook (e solo di esso).

# %% [markdown]
# La maggior parte del materiale presente nei notebook coincide con il materiale originale del **repository upstream** (<span style="color:blue">SciCompforChemists_UNIMORE</span>). Le relativamente poche aggiunte/precisazioni specificamente pensate per gli studenti del CdL in Chimica sono chiaramente identificabili, oltre per il fatto di essere scritte in italiano e non in inglese, per il richiamo iniziale in colore rosso: <span style="color:red">**CdL in Chimica</span>**
